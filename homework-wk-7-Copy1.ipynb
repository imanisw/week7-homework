# %% [markdown]
# ## Pandas - Importing data

# %%
## import the pandas library in this cell
import pandas as pd

# %% [markdown]
# ### Ingest the following dataset into this note:
#
# - ```ems_2019_first_6_months.csv``` into a dataframe named ```ems_19_first_df```

# %%
## import data and store in dataframe
ems_19_first_df = pd.read_csv("ems_2019_first_6_months.csv")

# %%
ems_19_first_
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             190010111  2019-01-01 00:24:51              SICK
# 1             190010112  2019-01-01 00:25:22              DRUG
# 2             190010113  2019-01-01 00:25:52              DRUG
# 3             190010114  2019-01-01 00:25:52             OBMAJ
# 4             190010115  2019-01-01 00:26:03               EDP
# ...                 ...                  ...               ...
# 754651        190010106  2019-01-01 00:24:12              DRUG
# 754652        190010107  2019-01-01 00:24:14               UNC
# 754653        190010108  2019-01-01 00:24:16            INJMAJ
# 754654        190010109  2019-01-01 00:24:23              CARD
# 754655        190010110  2019-01-01 00:24:35              DRUG
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 6            SICK
# 1                                 4            DRUG
# 2                                 4            DRUG
# 3                                 3           OBMAJ
# 4                                 7             EDP
# ...                             ...             ...
# 754651                            4            DRUG
# 754652                            2             UNC
# 754653                            3          INJMAJ
# 754654                            3            CARD
# 754655                            4            DRUG
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 0                               6    01/01/2019 12:25:28 AM
# 1                               4    01/01/2019 12:25:39 AM
# 2                               4    01/01/2019 12:25:57 AM
# 3                               3    01/01/2019 12:26:13 AM
# 4                               7    01/01/2019 12:26:12 AM
# ...                           ...                       ...
# 754651                          4    01/01/2019 12:28:52 AM
# 754652                          2    01/01/2019 12:24:38 AM
# 754653                          3    01/01/2019 12:25:50 AM
# 754654                          3    01/01/2019 12:25:08 AM
# 754655                          4    01/01/2019 12:25:28 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                                   Y                            37
# 1                                   Y                            17
# 2                                   Y                             5
# 3                                   Y                            21
# 4                                   Y                             9
# ...                               ...                           ...
# 754651                              Y                           280
# 754652                              Y                            24
# 754653                              Y                            94
# 754654                              Y                            45
# 754655                              Y                            53
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 0         01/01/2019 12:25:56 AM  ...            9.0                 2.0
# 1         01/01/2019 12:26:03 AM  ...           23.0                 9.0
# 2         01/01/2019 12:26:11 AM  ...           63.0                45.0
# 3         01/01/2019 12:26:24 AM  ...          106.0                32.0
# 4         01/01/2019 12:26:29 AM  ...          101.0                31.0
# ...                          ...  ...            ...                 ...
# 754651    01/01/2019 12:28:52 AM  ...           14.0                 3.0
# 754652    01/01/2019 12:24:57 AM  ...           14.0                 3.0
# 754653    01/01/2019 12:25:50 AM  ...           18.0                 4.0
# 754654    01/01/2019 12:25:27 AM  ...           50.0                14.0
# 754655    01/01/2019 12:25:40 AM  ...           62.0                47.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 0                   103.0                      1.0                  12.0
# 1                   111.0                      4.0                  13.0
# 2                   318.0                     22.0                   8.0
# 3                   410.0                     27.0                   8.0
# 4                   414.0                     27.0                   5.0
# ...                   ...                      ...                   ...
# 754651              105.0                      2.0                  12.0
# 754652              105.0                      2.0                  12.0
# 754653              105.0                      2.0                  12.0
# 754654              208.0                     10.0                  13.0
# 754655              311.0                     20.0                  10.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 0                     N                       N                 N
# 1                     N                       N                 N
# 2                     N                       N                 N
# 3                     N                       N                 N
# 4                     N                       N                 N
# ...                 ...                     ...               ...
# 754651                N                       N                 N
# 754652                N                       N                 N
# 754653                N                       N                 N
# 754654                N                       N                 N
# 754655                N                       N                 N
#
#         TRANSFER_INDICATOR       source
# 0                        N  chunk10.csv
# 1                        N  chunk10.csv
# 2                        N  chunk13.csv
# 3                        N  chunk14.csv
# 4                        N  chunk14.csv
# ...                    ...          ...
# 754651                   N  chunk82.csv
# 754652                   N  chunk82.csv
# 754653                   N  chunk82.csv
# 754654                   N  chunk82.csv
# 754655                   N  chunk82.csv
#
# [754656 rows x 32 columns]

# %%
## call the first 10 rows
df.head(10)
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        190010111  2019-01-01 00:24:51              SICK
# 1        190010112  2019-01-01 00:25:22              DRUG
# 2        190010113  2019-01-01 00:25:52              DRUG
# 3        190010114  2019-01-01 00:25:52             OBMAJ
# 4        190010115  2019-01-01 00:26:03               EDP
# 5        190073272  2019-01-07 17:49:43               EDP
# 6        190073416  2019-01-07 18:27:54               EDP
# 7        190081434  2019-01-08 10:28:31            UNKNOW
# 8        190081743  2019-01-08 11:43:35            UNKNOW
# 9        190081744  2019-01-08 11:43:48               EDP
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            6            SICK                          6
# 1                            4            DRUG                          4
# 2                            4            DRUG                          4
# 3                            3           OBMAJ                          3
# 4                            7             EDP                          7
# 5                            7             EDP                          7
# 6                            7             EDP                          7
# 7                            4          UNKNOW                          4
# 8                            4          UNKNOW                          4
# 9                            7             EDP                          7
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0    01/01/2019 12:25:28 AM                              Y
# 1    01/01/2019 12:25:39 AM                              Y
# 2    01/01/2019 12:25:57 AM                              Y
# 3    01/01/2019 12:26:13 AM                              Y
# 4    01/01/2019 12:26:12 AM                              Y
# 5    01/07/2019 05:49:50 PM                              Y
# 6    01/07/2019 06:28:33 PM                              Y
# 7    01/08/2019 10:29:19 AM                              Y
# 8    01/08/2019 11:43:47 AM                              Y
# 9    01/08/2019 11:43:59 AM                              Y
#
#    DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT  \
# 0                            37    01/01/2019 12:25:56 AM  ...            9.0
# 1                            17    01/01/2019 12:26:03 AM  ...           23.0
# 2                             5    01/01/2019 12:26:11 AM  ...           63.0
# 3                            21    01/01/2019 12:26:24 AM  ...          106.0
# 4                             9    01/01/2019 12:26:29 AM  ...          101.0
# 5                             7    01/07/2019 05:50:04 PM  ...           17.0
# 6                            39    01/07/2019 06:28:44 PM  ...            6.0
# 7                            48    01/08/2019 10:29:36 AM  ...            NaN
# 8                            12    01/08/2019 11:43:55 AM  ...            7.0
# 9                            11    01/08/2019 11:44:30 AM  ...           44.0
#
#   CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT  \
# 0                 2.0              103.0                      1.0
# 1                 9.0              111.0                      4.0
# 2                45.0              318.0                     22.0
# 3                32.0              410.0                     27.0
# 4                31.0              414.0                     27.0
# 5                 5.0              106.0                      2.0
# 6                 3.0              102.0                      2.0
# 7                 NaN                NaN                      NaN
# 8                 1.0              103.0                      2.0
# 9                16.0              204.0                      9.0
#
#   CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 0                  12.0                N                       N
# 1                  13.0                N                       N
# 2                   8.0                N                       N
# 3                   8.0                N                       N
# 4                   5.0                N                       N
# 5                  12.0                N                       N
# 6                  10.0                N                       N
# 7                   NaN                N                       N
# 8                  12.0                N                       N
# 9                  15.0                N                       N
#
#   STANDBY_INDICATOR  TRANSFER_INDICATOR        source
# 0                 N                   N   chunk10.csv
# 1                 N                   N   chunk10.csv
# 2                 N                   N   chunk13.csv
# 3                 N                   N   chunk14.csv
# 4                 N                   N   chunk14.csv
# 5                 N                   N  chunk149.csv
# 6                 N                   N  chunk149.csv
# 7                 N                   N  chunk149.csv
# 8                 N                   N  chunk149.csv
# 9                 N                   N  chunk149.csv
#
# [10 rows x 32 columns]

# %%
## call the last 5 rows
df.tail(5)
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 754651        190010106  2019-01-01 00:24:12              DRUG
# 754652        190010107  2019-01-01 00:24:14               UNC
# 754653        190010108  2019-01-01 00:24:16            INJMAJ
# 754654        190010109  2019-01-01 00:24:23              CARD
# 754655        190010110  2019-01-01 00:24:35              DRUG
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 754651                            4            DRUG
# 754652                            2             UNC
# 754653                            3          INJMAJ
# 754654                            3            CARD
# 754655                            4            DRUG
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 754651                          4    01/01/2019 12:28:52 AM
# 754652                          2    01/01/2019 12:24:38 AM
# 754653                          3    01/01/2019 12:25:50 AM
# 754654                          3    01/01/2019 12:25:08 AM
# 754655                          4    01/01/2019 12:25:28 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 754651                              Y                           280
# 754652                              Y                            24
# 754653                              Y                            94
# 754654                              Y                            45
# 754655                              Y                            53
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 754651    01/01/2019 12:28:52 AM  ...           14.0                 3.0
# 754652    01/01/2019 12:24:57 AM  ...           14.0                 3.0
# 754653    01/01/2019 12:25:50 AM  ...           18.0                 4.0
# 754654    01/01/2019 12:25:27 AM  ...           50.0                14.0
# 754655    01/01/2019 12:25:40 AM  ...           62.0                47.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 754651              105.0                      2.0                  12.0
# 754652              105.0                      2.0                  12.0
# 754653              105.0                      2.0                  12.0
# 754654              208.0                     10.0                  13.0
# 754655              311.0                     20.0                  10.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 754651                N                       N                 N
# 754652                N                       N                 N
# 754653                N                       N                 N
# 754654                N                       N                 N
# 754655                N                       N                 N
#
#         TRANSFER_INDICATOR       source
# 754651                   N  chunk82.csv
# 754652                   N  chunk82.csv
# 754653                   N  chunk82.csv
# 754654                   N  chunk82.csv
# 754655                   N  chunk82.csv
#
# [5 rows x 32 columns]

# %%
## call a 20 random rows
df.sample(20)
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 523783        191320065  2019-05-12 00:17:50            STNDBY
# 524119        191320439  2019-05-12 02:16:04            DIFFBR
# 508503        191282423  2019-05-08 14:08:03            DIFFBR
# 595934        191483342  2019-05-28 16:40:21            UNKNOW
# 408955        191040994  2019-04-14 05:33:48             OBMIS
# 744952        190011534  2019-01-01 05:39:44              DRUG
# 744368        190010485  2019-01-01 01:44:12            SICPED
# 237872        190623140  2019-03-03 18:30:06            PEDSTR
# 479733        191213513  2019-05-01 19:05:12            INJURY
# 439213        191112368  2019-04-21 15:06:19            INJURY
# 638390        191581400  2019-06-07 09:46:31              SICK
# 461210        191170226  2019-04-27 01:37:56              CARD
# 558731        191401094  2019-05-20 08:26:10            MVAINJ
# 623356        191544519  2019-06-03 22:17:06              SICK
# 686648        191691749  2019-06-18 11:35:36              EDPC
# 324592        190840003  2019-03-25 00:01:15               UNC
# 272466        190711427  2019-03-12 10:44:32            SICMIN
# 710525        191743749  2019-06-23 19:23:27            INJURY
# 152328        190403866  2019-02-09 22:42:33             ABDPN
# 399573        191020071  2019-04-12 00:27:26            DIFFBR
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
#
0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 523783              112.0                      6.0                  13.0
# 524119              110.0                      3.0                  13.0
# 508503              308.0                     13.0                   9.0
# 595934              201.0                      7.0                  15.0
# 408955              103.0                      1.0                  12.0
# 744952              301.0                     14.0                  12.0
# 744368              305.0                     19.0                   8.0
# 237872              103.0                      2.0                  12.0
# 479733              303.0                     16.0                   7.0
# 439213              302.0                     13.0                   8.0
# 638390              107.0                      3.0                  10.0
# 461210              104.0                      2.0                  12.0
# 558731              201.0                      7.0                  15.0
# 623356              111.0                      4.0                  13.0
# 686648              307.0                     15.0                   7.0
# 324592              402.0                     24.0                  14.0
# 272466              314.0                     22.0                   9.0
# 710525              204.0                      9.0                  15.0
# 152328              110.0                      5.0                  13.0
# 399573              308.0                     17.0                   8.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 523783                N                       N                 Y
# 524119                N                       N                 N
# 508503                N                       N                 N
# 595934                N                       N                 N
# 408955                N                       N                 N
# 744952                N                       N                 N
# 744368                N                       N                 N
# 237872                N                       N                 N
# 479733                N                       N                 N
# 439213                N                       N                 N
# 638390                N                       N                 N
# 461210                N                       N                 N
# 558731                N                       N                 N
# 623356                N                       N                 N
# 686648                N                       N                 N
# 324592                N                       N                 N
# 272466                N                       N                 N
# 710525                N                       N                 N
# 152328                N                       N                 N
# 399573                N                       N                 N
#
#         TRANSFER_INDICATOR        source
# 523783                   N  chunk155.csv
# 524119                   N  chunk155.csv
# 508503                   N  chunk154.csv
# 595934                   N  chunk155.csv
# 408955                   N  chunk153.csv
# 744952                   N   chunk29.csv
# 744368                   N   chunk27.csv
# 237872                   N  chunk152.csv
# 479733                   N  chunk154.csv
# 439213                   N  chunk154.csv
# 638390                   N  chunk156.csv
# 461210                   N  chunk154.csv
# 558731                   N  chunk155.csv
# 623356                   N  chunk156.csv
# 686648                   N  chunk156.csv
# 324592                   N  chunk153.csv
# 272466                   N  chunk152.csv
# 710525                   N  chunk156.csv
# 152328                   N  chunk151.csv
# 399573                   N  chunk153.csv
#
# [20 rows x 32 columns]

# %%
## get basic overview of the data
## what datatypes do the different columns hold?
## how many rows and columns are there

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754656 entries, 0 to 754655
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 754656 non-null  int64
#  1   INCIDENT_DATETIME               754656 non-null  object
#  2   INITIAL_CALL_TYPE               754656 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     754656 non-null  int64
#  4   FINAL_CALL_TYPE                 754656 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       754656 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       749544 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  754656 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    754656 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       748561 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         729221 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  754656 non-null  object
#  12  INCIDENT_RESPONSE_SECONDS_QY    729068 non-null  float64
#  13  INCIDENT_TRAVEL_TM_SECONDS_QY   729221 non-null  float64
#  14  FIRST_TO_HOSP_DATETIME          522462 non-null  object
#  15  FIRST_HOSP_ARRIVAL_DATETIME     518867 non-null  object
#  16  INCIDENT_CLOSE_DATETIME         754540 non-null  object
#  17  HELD_INDICATOR                  754656 non-null  object
#  18  INCIDENT_DISPOSITION_CODE       748265 non-null  float64
#  19  BOROUGH                         754656 non-null  object
#  20  INCIDENT_DISPATCH_AREA          754656 non-null  object
#  21  ZIPCODE                         745086 non-null  float64
#  22  POLICEPRECINCT                  745102 non-null  float64
#  23  CITYCOUNCILDISTRICT             745071 non-null  float64
#  24  COMMUNITYDISTRICT               745101 non-null  float64
#  25  COMMUNITYSCHOOLDISTRICT         744542 non-null  float64
#  26  CONGRESSIONALDISTRICT           745071 non-null  float64
#  27  REOPEN_INDICATOR                754656 non-null  object
#  28  SPECIAL_EVENT_INDICATOR         754656 non-null  object
#  29  STANDBY_INDICATOR               754656 non-null  object
#  30  TRANSFER_INDICATOR              754656 non-null  object
#  31  source                          754656 non-null  object
# dtypes: float64(9), int64(4), object(19)
# memory usage: 184.2+ MB

# %% [markdown]
# ### In three separate cells, ingest the 3 other related datasets into this notebook:
#
# - ```ems_2019_last_6_months.csv``` into a dataframe named ```ems_19_last_df```
# - ```ems_2020_first_6_months.csv``` into a dataframe named ```ems_20_first_df```
# - ```ems_2020_last_6_months.csv``` into a dataframe named ```ems_20_last_df```
#
# We want to combine all 4 dataframes so we can run an analysis on the combined dataframes

# %%
### For last 6 months of 2019
## call the dataframe to see what you have
ems_19_last_df = pd.read_csv('wk7/ems_2019_last_6_months.csv')
ems_19_last_df
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             191853909  2019-07-04 21:07:53              DRUG
# 1             191864927  2019-07-05 21:09:53            MVAINJ
# 2             191870823  2019-07-06 05:32:12            INJURY
# 3             191870824  2019-07-06 05:33:49               UNC
# 4             191870897  2019-07-06 06:20:26            INJURY
# ...                 ...                  ...               ...
# 781735        192702998  2019-09-27 16:20:29               EDP
# 781736        192704269  2019-09-27 21:05:14             OTHER
# 781737        193012678  2019-10-28 15:01:30            MVAINJ
# 781738        193330212  2019-11-29 01:16:42               EDP
# 781739        193634478  2019-12-29 23:59:34               EDP
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 4            DRUG
# 1                                 4          MVAINJ
# 2                                 5          INJURY
# 3                                 2             UNC
# 4                                 5          INJURY
# ...                             ...             ...
# 781735                            7          UNKNOW
# 781736                            6           OTHER
# 781737                            4          MVAINJ
# 781738                            7             EDP
# 781739                            7             EDP
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 0                               4    07/04/2019 09:08:16 PM
# 1                               4    07/05/2019 09:10:10 PM
# 2                               5    07/06/2019 05:32:49 AM
# 3                               2    07/06/2019 05:33:57 AM
# 4                               5    07/06/2019 06:20:43 AM
# ...                           ...                       ...
# 781735                          4    09/27/2019 04:21:09 PM
# 781736                          6    09/27/2019 09:05:26 PM
# 781737                          4    10/28/2019 03:01:30 PM
# 781738                          7    11/29/2019 01:17:36 AM
# 781739                          7                       NaN
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                                   Y                            23
# 1                                   Y                            17
# 2                                   Y                            37
# 3                                   Y                             8
# 4                                   Y                            17
# ...                               ...                           ...
# 781735                              Y                            40
# 781736                              Y                            12
# 781737                              Y                             0
# 781738                              Y                            54
# 781739                              N                             0
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 0         07/04/2019 09:08:26 PM  ...            NaN                 NaN
# 1         07/05/2019 09:10:20 PM  ...            NaN                 NaN
# 2         07/06/2019 05:33:40 AM  ...           47.0                12.0
# 3         07/06/2019 05:34:25 AM  ...           32.0                 9.0
# 4         07/06/2019 06:20:53 AM  ...            NaN                 NaN
# ...                          ...  ...            ...                 ...
# 781735    09/27/2019 04:21:21 PM  ...          100.0                31.0
# 781736    09/27/2019 09:07:15 PM  ...           43.0                18.0
# 781737    10/28/2019 03:01:30 PM  ...          109.0                20.0
# 781738    11/29/2019 01:17:53 AM  ...           28.0                 9.0
# 781739                       NaN  ...           41.0                17.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 0
0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 0                   414.0                     27.0                   5.0
# 1                   203.0                     12.0                  15.0
# 2                   311.0                     20.0                  11.0
# 3                   207.0                     10.0                  13.0
# 4                   412.0                     28.0                   5.0
# ...                   ...                      ...                   ...
# 741802              410.0                     27.0                   5.0
# 741803              315.0                     21.0                  11.0
# 741804              109.0                      6.0                  13.0
# 741805              105.0                      2.0                  12.0
# 741806              102.0                      2.0                  12.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 0                     N                       N                 N
# 1                     N                       N                 N
# 2                     N                       N                 N
# 3                     N                       N                 N
# 4                     N                       N                 N
# ...                 ...                     ...               ...
# 741802                N                       N                 N
# 741803                N                       N                 N
# 741804                N                       N                 N
# 741805                N                       N                 N
# 741806                N                       N                 N
#
#         TRANSFER_INDICATOR        source
# 0                        N  chunk148.csv
# 1                        N  chunk148.csv
# 2                        N  chunk148.csv
# 3                        N  chunk148.csv
# 4                        N  chunk148.csv
# ...                    ...           ...
# 741802                   N  chunk172.csv
# 741803                   N  chunk172.csv
# 741804                   N  chunk172.csv
# 741805                   N   chunk81.csv
# 741806                   N   chunk81.csv
#
# [741807 rows x 32 columns]

# %%
### For last 6 months of 2020
## call the dataframe to see what you have
ems_20_last_df = pd.read_csv('wk7/ems_2020_last_6_months.csv')
ems_20_last_df
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             201853344  2020-07-03 19:51:35            MVAINJ
# 1             201861781  2020-07-04 13:38:45            INJURY
# 2             201862931  2020-07-04 19:06:08            INJURY
# 3             201870048  2020-07-05 00:09:31              SICK
# 4             201870159  2020-07-05 00:31:24              EDPC
# ...                 ...                  ...               ...
# 670750        203664156  2020-12-31 23:58:15            DIFFBR
# 670751        203664157  2020-12-31 23:58:27            INJURY
# 670752        203664158  2020-12-31 23:58:38            CARDBR
# 670753        203664159  2020-12-31 23:58:46            MVAINJ
# 670754        203664161  2020-12-31 23:59:13            CARDBR
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 4          MVAINJ
# 1                                 5          INJURY
# 2                                 5          INJURY
# 3                                 6            SICK
# 4                                 7            SICK
# ...                             ...             ...
# 670750                            2          DIFFBR
# 670751                            5          INJURY
# 670752                            2          CARDBR
# 670753                            4          MVAINJ
# 670754                            2          CARDBR
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 0                               4    07/03/2020 07:52:54 PM
# 1                               5    07/04/2020 01:38:55 PM
# 2                               5    07/04/2020 07:06:34 PM
# 3                               6                       NaN
# 4                               6                       NaN
# ...                           ...                       ...
# 670750                          2    12/31/2020 11:58:26 PM
# 670751                          5    12/31/2020 11:59:57 PM
# 670752                          2    12/31/2020 11:59:32 PM
# 670753                          4    12/31/2020 11:59:37 PM
# 670754                          2    01/01/2021 12:00:22 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                                   Y                            79
# 1                                   Y                            10
# 2                                   Y                            26
# 3                                   N                             0
# 4                                   N                             0
# ...                               ...                           ...
# 670750                              Y                            11
# 670751                              Y                            90
# 670752                              Y                            54
# 670753                              Y                            51
# 670754                              Y                            69
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 0         07/03/2020 07:53:13 PM  ...            NaN                 NaN
# 1         07/04/2020 01:39:01 PM  ...           20.0                 3.0
# 2         07/04/2020 07:06:53 PM  ...           60.0                47.0
# 3                            NaN  ...           46.0                14.0
# 4                            NaN  ...           43.0                17.0
# ...                          ...  ...            ...                 ...
# 670750    12/31/2020 11:59:10 PM  ...           79.0                36.0
# 670751    01/01/2021 12:01:00 AM  ...           41.0                17.0
# 670752    12/31/2020 11:59:40 PM  ...           30.0                 7.0
# 670753    01/01/2021 12:01:00 AM  ...           48.0                17.0
# 670754    01/01/2021 12:01:10 AM  ...           77.0                36.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 0                     NaN                      NaN                   NaN
# 1                   107.0                      3.0                  10.0
# 2                   313.0                     21.0                   8.0
# 3                   205.0                     10.0                  15.0
# 4                   209.0                     12.0                  15.0
# ...                   ...                      ...                   ...
# 670750              303.0                     14.0                   7.0
# 670751              202.0                      8.0                  15.0
# 670752              109.0                      6.0                  13.0
# 670753              206.0                     12.0                  15.0
# 670754              308.0                     16.0                   9.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 0                     N                       N                 N
# 1                     N                       N                 N
# 2                     N                       N                 N
# 3                     N                       N                 N
# 4                     N                       N                 N
# ...                 ...                     ...               ...
# 670750                N                       N                 N
# 670751                N                       N                 N
# 670752                N                       N                 N
# 670753                N                       N                 N
# 670754                N                       N                 N
#
#         TRANSFER_INDICATOR        source
# 0                        N  chunk172.csv
# 1                        N  chunk172.csv
# 2                        N  chunk172.csv
# 3                        N  chunk172.csv
# 4                        N  chunk172.csv
# ...                    ...           ...
# 670750                   N  chunk214.csv
# 670751                   N  chunk214.csv
# 670752                   N  chunk214.csv
# 670753                   N  chunk214.csv
# 670754                   N  chunk214.csv
#
# [670755 rows x 32 columns]

# %% [markdown]
# ### Check if all the column headers are identical (down to the same order)
# We need to confirm they are the same before we combine them

# %%
## headers for first 6 months of 2019
headersf19 = list(ems_19_first_df.columns)
headersf19
# Out:
# ['CAD_INCIDENT_ID',
#  'INCIDENT_DATETIME',
#  'INITIAL_CALL_TYPE',
#  'INITIAL_SEVERITY_LEVEL_CODE',
#  'FINAL_CALL_TYPE',
#  'FINAL_SEVERITY_LEVEL_CODE',
#  'FIRST_ASSIGNMENT_DATETIME',
#  'VALID_DISPATCH_RSPNS_TIME_INDC',
#  'DISPATCH_RESPONSE_SECONDS_QY',
#  'FIRST_ACTIVATION_DATETIME',
#  'FIRST_ON_SCENE_DATETIME',
#  'VALID_INCIDENT_RSPNS_TIME_INDC',
#  'INCIDENT_RESPONSE_SECONDS_QY',
#  'INCIDENT_TRAVEL_TM_SECONDS_QY',
#  'FIRST_TO_HOSP_DATETIME',
#  'FIRST_HOSP_ARRIVAL_DATETIME',
#  'INCIDENT_CLOSE_DATETIME',
#  'HELD_INDICATOR',
#  'INCIDENT_DISPOSITION_CODE',
#  'BOROUGH',
#  'INCIDENT_DISPATCH_AREA',
#  'ZIPCODE',
#  'POLICEPRECINCT',
#  'CITYCOUNCILDISTRICT',
#  'COMMUNITYDISTRICT',
#  'COMMUNITYSCHOOLDISTRICT',
#  'CONGRESSIONALDISTRICT',
#  'REOPEN_INDICATOR',
#  'SPECIAL_EVENT_INDICATOR',
#  'STANDBY_INDICATOR',
#  'TRANSFER_INDICATOR',
#  'source']

# %%
## headers for first 6 months of 2020
headersf20 = list(ems_20_first_df.columns)
headersf20
# Out:
# ['CAD_INCIDENT_ID',
#  'INCIDENT_DATETIME',
#  'INITIAL_CALL_TYPE',
#  'INITIAL_SEVERITY_LEVEL_CODE',
#  'FINAL_CALL_TYPE',
#  'FINAL_SEVERITY_LEVEL_CODE',
#  'FIRST_ASSIGNMENT_DATETIME',
#  'VALID_DISPATCH_RSPNS_TIME_INDC',
#  'DISPATCH_RESPONSE_SECONDS_QY',
#  'FIRST_ACTIVATION_DATETIME',
#  'FIRST_ON_SCENE_DATETIME',
#  'VALID_INCIDENT_RSPNS_TIME_INDC',
#  'INCIDENT_RESPONSE_SECONDS_QY',
#  'INCIDENT_TRAVEL_TM_SECONDS_QY',
#  'FIRST_TO_HOSP_DATETIME',
#  'FIRST_HOSP_ARRIVAL_DATETIME',
#  'INCIDENT_CLOSE_DATETIME',
#  'HELD_INDICATOR',
#  'INCIDENT_DISPOSITION_CODE',
#  'BOROUGH',
#  'INCIDENT_DISPATCH_AREA',
#  'ZIPCODE',
#  'POLICEPRECINCT',
#  'CITYCOUNCILDISTRICT',
#  'COMMUNITYDISTRICT',
#  'COMMUNITYSCHOOLDISTRICT',
#  'CONGRESSIONALDISTRICT',
#  'REOPEN_INDICATOR',
#  'SPECIAL_EVENT_INDICATOR',
#  'STANDBY_INDICATOR',
#  'TRANSFER_INDICATOR',
#  'source']

# %%
## check if they are the same
headersf19 == headersf20
# Out:
# True

# %%
## creater headers list for last 6 months of 2019 and 2020
headersl19 = list(ems_19_last_df.columns)
headersl20 = list(ems_20_last_df.columns)

headersl19
headersl20
# Out:
# ['CAD_INCIDENT_ID',
#  'INCIDENT_DATETIME',
#  'INITIAL_CALL_TYPE',
#  'INITIAL_SEVERITY_LEVEL_CODE',
#  'FINAL_CALL_TYPE',
#  'FINAL_SEVERITY_LEVEL_CODE',
#  'FIRST_ASSIGNMENT_DATETIME',
#  'VALID_DISPATCH_RSPNS_TIME_INDC',
#  'DISPATCH_RESPONSE_SECONDS_QY',
#  'FIRST_ACTIVATION_DATETIME',
#  'FIRST_ON_SCENE_DATETIME',
#  'VALID_INCIDENT_RSPNS_TIME_INDC',
#  'INCIDENT_RESPONSE_SECONDS_QY',
#  'INCIDENT_TRAVEL_TM_SECONDS_QY',
#  'FIRST_TO_HOSP_DATETIME',
#  'FIRST_HOSP_ARRIVAL_DATETIME',
#  'INCIDENT_CLOSE_DATETIME',
#  'HELD_INDICATOR',
#  'INCIDENT_DISPOSITION_CODE',
#  'BOROUGH',
#  'INCIDENT_DISPATCH_AREA',
#  'ZIPCODE',
#  'POLICEPRECINCT',
#  'CITYCOUNCILDISTRICT',
#  'COMMUNITYDISTRICT',
#  'COMMUNITYSCHOOLDISTRICT',
#  'CONGRESSIONALDISTRICT',
#  'REOPEN_INDICATOR',
#  'SPECIAL_EVENT_INDICATOR',
#  'STANDBY_INDICATOR',
#  'TRANSFER_INDICATOR',
#  'source']

# %%
## check if one of the first is equal to one of the last
headersf19 == headersf20
# Out:
# True

# %%
## now confirm that the two lasts are the same
headersl19 == headersl20
# Out:
# True

# %% [markdown]
# ## Combine the 4 dataframes

# %%
## create a list to combine all 
comb_df = pd.concat([ems_19_first_df,ems_19_last_df,ems_20_first_df,ems_20_last_df])

# %%
## combine the dfs
comb_df
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0
N                       N                 N
#
#         TRANSFER_INDICATOR        source
# 0                        N   chunk10.csv
# 1                        N   chunk10.csv
# 2                        N   chunk13.csv
# 3                        N   chunk14.csv
# 4                        N   chunk14.csv
# ...                    ...           ...
# 670750                   N  chunk214.csv
# 670751                   N  chunk214.csv
# 670752                   N  chunk214.csv
# 670753                   N  chunk214.csv
# 670754                   N  chunk214.csv
#
# [2948958 rows x 32 columns]

# %% [markdown]
# #### Confirm that their row totals add up to the correct number

# %%
## how many rows does the combined df have
comb_df.shape
# Out:
# (2948958, 32)

# %%
## get total rows when you add up all the individual dataframes
comb_df.shape[0] == ems_19_first_df.shape[0] + ems_19_last_df.shape[0] + ems_20_first_df.shape[0] + ems_20_last_df.shape[0]
# Out:
# True

# %% [markdown]
# ## Ingest Massive Dataset
#
# Step 1. Open this dataset in Excel first. What happened?
#
# Step 2. Open this data set in Pandas.

# %%
## import global_temps.csv into a df called temps_df
## when i tried to open this file i got message saying "this dataset is too large for excel grid"
temps_df = pd.read_csv('wk7/global_temps.csv')
temps_df
# Out:
#                 Region  Country                  City  Month  Day  Year  \
# 0               Africa  Algeria               Algiers      1    1  1995
# 1               Africa  Algeria               Algiers      1    2  1995
# 2               Africa  Algeria               Algiers      1    3  1995
# 3               Africa  Algeria               Algiers      1    4  1995
# 4               Africa  Algeria               Algiers      1    5  1995
# ...                ...      ...                   ...    ...  ...   ...
# 2906322  North America       US  San Juan Puerto Rico      7   27  2013
# 2906323  North America       US  San Juan Puerto Rico      7   28  2013
# 2906324  North America       US  San Juan Puerto Rico      7   29  2013
# 2906325  North America       US  San Juan Puerto Rico      7   30  2013
# 2906326  North America       US  San Juan Puerto Rico      7   31  2013
#
#          AvgTemperature
# 0                  64.2
# 1                  49.4
# 2                  48.8
# 3                  46.4
# 4                  47.9
# ...                 ...
# 2906322            82.4
# 2906323            81.6
# 2906324            84.2
# 2906325            83.8
# 2906326            83.6
#
# [2906327 rows x 7 columns]

# %% [markdown]
# ## How many rows of data does this dataset have?

# %%
## 2_906_327
temps_df.shape
## 2,906,327 rows
# Out:
# (2906327, 7)

# %% [markdown]
# ## Targeting an Excel sheet
#
# We need the Customs and Border Protection data in this ```multi-data.xlsx``` workbook.
#
# Note that this is an excerpt of the actual CBP data.

# %%
### import it here
df = pd.read_excel("wk7/multi-data.xlsx", sheet_name = "CBP", skiprows=5)
df
# Out:
#                 Unnamed: 0           Unnamed: 1        Unnamed: 2  \
# 0                  date_in             date_out  hours_in_custody
# 1      2017-01-20 00:10:00  2017-01-20 10:08:00              9.95
# 2      2017-01-20 00:15:00  2017-01-24 17:30:00        113.233333
# 3      2017-01-20 00:22:00  2017-01-24 17:47:00        113.416667
# 4      2017-01-20 00:30:00  2017-01-21 06:35:00         30.083333
# ...                    ...                  ...               ...
# 95717  2018-06-02 13:00:00  2018-06-04 09:05:00         44.066667
# 95718  2018-06-02 13:00:00  2018-06-04 09:05:00         44.066667
# 95719  2018-06-02 13:05:00  2018-06-05 23:35:00         82.483333
# 95720  2018-06-02 13:05:00  2018-06-04 00:54:00              35.8
# 95721  2018-06-02 13:20:00  2018-06-06 07:27:00              90.1
#
#         Unnamed: 3 Unnamed: 4   Unnamed: 5 Unnamed: 6  Unnamed: 7  \
# 0        age_group     gender  citizenship     border      sector
# 1        6-8 years     Female  EL SALVADOR        SBO  (b)(7)(E )
# 2        3-5 years     Female    GUATEMALA        SBO  (b)(7)(E )
# 3        3-5 years     Female       BRAZIL        SBO  (b)(7)(E )
# 4      12-14 years       Male  EL SALVADOR        SBO  (b)(7)(E )
# ...            ...        ...          ...        ...         ...
# 95717  15-18 years       Male  EL SALVADOR        SBO  (b)(7)(E )
# 95718  12-14 years       Male  EL SALVADOR        SBO  (b)(7)(E )
# 95719    6-8 years     Female    GUATEMALA        SBO  (b)(7)(E )
# 95720  15-18 years       Male    GUATEMALA        SBO  (b)(7)(E )
# 95721    6-8 years       Male    GUATEMALA        SBO  (b)(7)(E )
#
#          Unnamed: 8
# 0      field_office
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 95717           NaN
# 95718           NaN
# 95719           NaN
# 95720           NaN
# 95721           NaN
#
# [95722 rows x 9 columns]

# %%
## call the top 15 rows
df.head(15)
# Out:
#              Unnamed: 0           Unnamed: 1        Unnamed: 2    Unnamed: 3  \
# 0               date_in             date_out  hours_in_custody     age_group
# 1   2017-01-20 00:10:00  2017-01-20 10:08:00              9.95     6-8 years
# 2   2017-01-20 00:15:00  2017-01-24 17:30:00        113.233333     3-5 years
# 3   2017-01-20 00:22:00  2017-01-24 17:47:00        113.416667     3-5 years
# 4   2017-01-20 00:30:00  2017-01-21 06:35:00         30.083333   12-14 years
# 5   2017-01-20 00:30:00  2017-01-21 13:03:00         36.533333     3-5 years
# 6   2017-01-20 00:30:00  2017-01-21 15:30:00         38.983333  Under 1 year
# 7   2017-01-20 00:35:00  2017-01-21 11:52:00         35.266667     6-8 years
# 8   2017-01-20 00:35:00  2017-01-20 15:14:00         14.633333     6-8 years
# 9   2017-01-20 00:35:00  2017-01-21 11:52:00         35.266667     3-5 years
# 10  2017-01-20 00:35:00  2017-01-21 11:52:00         35.266667    9-11 years
# 11  2017-01-20 00:45:00  2017-01-20 13:15:00              12.5   15-18 years
# 12  2017-01-20 01:19:00  2017-01-21 02:30:00         25.166667   15-18 years
# 13  2017-01-20 01:19:00  2017-01-21 02:30:00         25.166667   15-18 years
# 14  2017-01-20 01:20:00  2017-01-24 17:30:00        112.166667     6-8 years
#
#    Unnamed: 4   Unnamed: 5 Unnamed: 6  Unnamed: 7    Unnamed: 8
# 0      gender  citizenship     border      sector  field_office
# 1      Female  EL SALVADOR        SBO  (b)(7)(E )           NaN
# 2      Female    GUATEMALA        SBO  (b)(7)(E )           NaN
# 3      Female       BRAZIL        SBO  (b)(7)(E )           NaN
# 4        Male  EL SALVADOR        SBO  (b)(7)(E )           NaN
# 5        Male     HONDURAS        SBO  (b)(7)(E )           NaN
# 6        Male     HONDURAS        SBO  (b)(7)(E )           NaN
# 7        Male    GUATEMALA        SBO  (b)(7)(E )           NaN
# 8        Male    GUATEMALA        SBO  (b)(7)(E )           NaN
# 9        Male    GUATEMALA        SBO  (b)(7)(E )           NaN
# 10       Male    GUATEMALA        SBO  (b)(7)(E )           NaN
# 11       Male  EL SALVADOR        SBO  (b)(7)(E )           NaN
# 12       Male        INDIA        SBO  (b)(7)(E )           NaN
# 13       Male        INDIA        SBO  (b)(7)(E )           NaN
# 14       Male     HONDURAS        SBO  (b)(7)(E )           NaN
